# %% [markdown]
# 2021-01-17 11:14:20
# t5运行自动摘要，法研杯数据

# %%
# !pip install tqdm bert4keras rouge nltk sentencepiece
# Out:
# Looking in indexes: https://pypi.tuna.tsinghua.edu.cn/simple
# ...
#      |████████████████████████████████| 1.2 MB 18.9 MB/s eta 0:00:01
# ...

# %%
# !python x4.py
# Out:
# /home/xuehp/anaconda3/envs/t5/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/xuehp/anaconda3/envs/t5/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/xuehp/anaconda3/envs/t5/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# 2021-01-17 11:42:24
#
# 太费时，取消了。
#
# 直接看结果。
#
# 12小时 * 40 epoch = 480小时
